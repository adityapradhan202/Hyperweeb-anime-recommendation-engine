# %%
import pandas as pd
import numpy as np

anime_df = pd.read_csv('anime_data_2023.csv')

drop_cols = ['Rank', 'Start_date', 'End_date', 'Popularity', 'Members']
anime_df = anime_df.drop(drop_cols, axis=1)

anime_df['Genre'] = anime_df['Genre'].apply(lambda genres: str(genres).split(", "))

# %%
anime_df
# Out:
#                                                  Title  \
# 0    Shingeki no Kyojin: The Final Season - Kankets...
# 1                     Fullmetal Alchemist: Brotherhood
# 2                            Bleach: Sennen Kessen-hen
# 3                                          Steins;Gate
# 4                                             Gintama°
# ..                                                 ...
# 245                                          Blue Lock
# 246  Detective Conan Movie 06: The Phantom of Baker...
# 247                      Diamond no Ace: Second Season
# 248                                Hibike! Euphonium 2
# 249                                      Ashita no Joe
#
#                                    Genre                    Studio     Type  \
# 0              [Action, Drama, Suspense]                     MAPPA  Special
# 1    [Action, Adventure, Drama, Fantasy]                     Bones       TV
# 2           [Action, Adventure, Fantasy]                   Pierrot       TV
# 3              [Drama, Sci-Fi, Suspense]                 White Fox       TV
# 4               [Action, Comedy, Sci-Fi]     Bandai Namco Pictures       TV
# ..                                   ...                       ...      ...
# 245                             [Sports]                      8bit       TV
# 246                 [Adventure, Mystery]         TMS Entertainment    Movie
# 247                             [Sports]  Production I.G, Madhouse       TV
# 248                              [Drama]           Kyoto Animation       TV
# 249                      [Drama, Sports]          Mushi Production       TV
#
#      Episodes  Duration  Score
# 0         2.0        61   9.17
# 1        64.0        24   9.11
# 2        13.0        24   9.09
# 3        24.0        24   9.08
# 4        51.0        24   9.07
# ..        ...       ...    ...
# 245      24.0        24   8.30
# 246       1.0       107   8.30
# 247      51.0        24   8.30
# 248      13.0        23   8.30
# 249      79.0        25   8.29
#
# [250 rows x 7 columns]
